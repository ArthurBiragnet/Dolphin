# %%
#Library
import requests
import json
from datetime import datetime
import scipy.optimize as optimize
import math
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 1000)
pd.set_option("display.precision", 12)
import warnings
warnings.filterwarnings('ignore')

# %%
def get_data(endpointApi, date=None, full_response=False, columns=list()):
    URL = 'https://dolphin.jump-technology.com:8443/api/v1/'
    AUTH = ('EPITA_GROUPE10', 'LRNSpHqMgGv86AH5')
    
    payload = {'date': date, 'fullResponse': full_response}
    res = requests.get(URL + endpointApi,
                      params=payload,
                      auth=AUTH,
                      verify=False)
    return res.content.decode('utf-8')

# %%
def put_data(endpointApi, content):
    URL = 'https://dolphin.jump-technology.com:8443/api/v1/'
    AUTH = ('EPITA_GROUPE10', 'LRNSpHqMgGv86AH5')
    
    res = requests.put(url=URL + endpointApi,
                      data=json.dumps(content),
                      auth=AUTH,
                      headers = {"content-type": "application/json"},
                      verify=False)
    return res.content.decode('utf-8')

# %%
def put_data(endpointApi, content):
    URL = 'https://dolphin.jump-technology.com:8443/api/v1/'
    AUTH = ('EPITA_GROUPE10', 'LRNSpHqMgGv86AH5')
    
    res = requests.put(url=URL + endpointApi,
                      data=json.dumps(content),
                      auth=AUTH,
                      verify=False)
    return res.content.decode('utf-8')

# %%
def post_data(endpointApi, content):
    URL = 'https://dolphin.jump-technology.com:8443/api/v1/'
    AUTH = ('EPITA_GROUPE10', 'LRNSpHqMgGv86AH5')
    #json.dumps(content),
    res = requests.post(url=URL + endpointApi,
                      data=content,
                      auth=AUTH,
                      headers = {"content-type": "application/json"},
                      verify=False)
    return res.content.decode('utf-8')

# %% [markdown]
# Conversion chaque valeur en le type approprié :

# %%
def convert_currency(value, df_currency_rate):
    value, currency_name = value.split(' ')
    rate = currencyRateToEUR(currency_name, df_currency_rate)
    
    new_value = float(value.replace(',', '.')) * rate
    return new_value

def convert_datetime(value):
    return datetime.strptime(value, '%Y-%m-%d').date()

def convert_float(value):
    return float(value.replace(',', '.'))

def convert_int(value):
    return int(value)

def convert_boolean(value):
    return json.loads(value)

def df_convert_type(df, df_currency_rate):
        for col in df.columns:
            convert_values = []
            for elt in df[col]:
                if elt is np.nan:
                    convert_values.append(np.nan)
                    continue

                elt_type = elt['type']
                elt_value = elt['value']
                if elt_type == 'currency_value':
                    elt_value = convert_currency(elt_value, df_currency_rate)
                elif elt_type == 'date':
                    elt_value = convert_datetime(elt_value)
                elif elt_type in ['double', 'percent']:
                    elt_value = convert_float(elt_value)
                elif elt_type in ['asset', 'int32']:
                    elt_value = convert_int(elt_value)
                elif elt_type == 'boolean':
                    elt_value = convert_boolean(elt_value)
                elif elt_type not in ['asset_type', 'string', 'asset_currency', 'date-time',
                                     'asset_sub_type', 'asset_status', 'asset_quote_type',
                                     'liquidity_algorithm', 'portfolio_lock_mode', 'portfolio_type']:
                    print(elt)
                convert_values.append(elt_value)
            df[col] = convert_values
        return df

# %% [markdown]
# Création de la table des taux en EUR :
#
# [Est-ce qu'on donne la posibilité de changer la currency dst en fonction de la currency du portfolio ?]

# %%
def getCurrencyRate():
    d = []
    currency_json = json.loads(get_data('currency'))
    for currency in currency_json:
        currency_id = currency.get('id')
        rate = get_data('currency/rate/{}/to/EUR'.format(currency_id))
        if len(rate) == 0:
            continue
        rate_value = json.loads(rate)['rate']['value']
        d.append([currency_id, convert_float(rate_value)])
    return pd.DataFrame(d, columns=['currency src', 'rate'])
    
"""df_currency_rate = getCurrencyRate()
df_currency_rate"""
# Out:
# 'df_currency_rate = getCurrencyRate()\ndf_currency_rate'

# %% [markdown]
# [TEST] Taux de convertion entre USD et EUR :

# %%
def currencyRateToEUR(cur_src, df_currency_rate):
    return df_currency_rate[df_currency_rate['currency src'] == cur_src]['rate'].values[0]

#currencyRateToEUR('USD', df_currency_rate)

# %% [markdown]
# [TEST] La database complète de tous les asset :

# %%
"""data = get_data('asset/')
df = pd.read_json(data)
df_assets = df_convert_type(df, df_currency_rate)
df_assets"""
# Out:
# "data = get_data('asset/')\ndf = pd.read_json(data)\ndf_assets = df_convert_type(df, df_currency_rate)\ndf_assets"

# %% [markdown]
# Récupération de la liste d'actifs en base :
#
# [On prend juste ces valeurs comme dans l'exemple ou toutes les valeurs des assets ?]

# %%
def get_df_asset(asset_date, df_currency_rate, asset_id='ASSET_DATABASE_ID', asset_label='LABEL',
                 asset_type='TYPE', asset_last_close_value='LAST_CLOSE_VALUE_IN_CURR', asset_min_buy_amount='MIN_BUY_AMOUNT'):
    data = get_data('asset?columns={}&columns={}&columns={}&columns={}&columns={}&columns=nav&date={}&columns=CREATION_DATE'
                   .format(asset_id, asset_label, asset_type, asset_last_close_value, asset_min_buy_amount, asset_date))
    df_asset = pd.read_json(data)
    df_asset = df_convert_type(df_asset, df_currency_rate)
    df_asset = df_asset[(df_asset['LAST_CLOSE_VALUE_IN_CURR'].notna()) | (df_asset['TYPE'] == 'PORTFOLIO')].reset_index() #FIXME es assets avec LAST_CLOSE_VALUE_IN_CURR = NAN bug lors de l'ajout dans un portefeuille
    return df_asset

#df_ETF = get_df_asset('2016-06-01', df_currency_rate)
#df_ETF

# %% [markdown]
# Récupération des valeurs de cotation:
#
# Cotation de l'actif 1845 en fonction de l'id et de la date de debut et fin :

# %%
def get_cotation_values(asset_id, start_date, end_date, df_currency_rate):
    data = get_data('asset/{}/quote?start_date={}&end_date={}'
                    .format(asset_id, start_date, end_date))
    df_cotation = pd.read_json(data)
    df_cotation = df_convert_type(df_cotation, df_currency_rate)
    return df_cotation

#df_cotation = get_cotation_values('1845', '2016-06-01', '2020-09-30', df_currency_rate)
#df_cotation

# %% [markdown]
# Récupération de la liste des ratios :

# %%
def get_ratio(df_currency_rate):
    data = get_data('ratio')
    df_ratio = pd.read_json(data)
    return df_ratio

#df_ratio = get_ratio(df_currency_rate)
#df_ratio

# %% [markdown]
# Calcul de ratios :

# %%
def post_ratio(ratios, assets_id, start_date, end_date, bench=None, frequency=None):
    #start_date = datetime.strptime(start_date, "%Y-%m-%d").isoformat()
    #end_date = datetime.strptime(end_date, "%Y-%m-%d").isoformat()
    
    #payload = {'ratio':ratios, 'asset':assets_id, 'startDate':, 'endDate':None, 'benchmark':bench, 'frequency':frequency}
    payload = "{{'ratio'={},'asset'={},'start_date'={},'end_date'={}, 'bench'=null, 'frequency':null}}".format(ratios, assets_id, start_date, end_date)
    reponse = post_data('ratio/invoke', payload)
    return reponse
    
#get Rendement_annualise, Sharpe, Volatilite, Rendement de l'asset 1845 et 1991 entre '2016-06-01' et '2020-09-30'
#post_ratio([9, 12, 10, 13], [1845], '2016-06-01', '2020-09-30')

# %%
def get_df_ratios(assets_id, begin_date, end_date):
    json_ratios = json.loads(post_ratio([10, 12, 13], assets_id, begin_date, end_date))
    ratios = []
    for asset_id in assets_id:
        str_asset_id = str(asset_id)
        volatilite = convert_float(json_ratios[str_asset_id]['10']['value'])
        sharpe = convert_float(json_ratios[str_asset_id]['12']['value'])
        rendement = convert_float(json_ratios[str_asset_id]['13']['value'])
        ratios.append([asset_id, volatilite, rendement, sharpe])
    return pd.DataFrame(ratios, columns=['ASSET_DATABASE_ID', 'volatilite', 'rendement', 'sharpe'])

#get_df_ratios([1845, 1991], '2016-06-01', '2020-09-30')

# %% [markdown]
# Recupération du portfolio ID :

# %%
def get_portfolio_id(df_assets, label):
    portfolio_id = df_assets.loc[(df_assets['TYPE'] == 'PORTFOLIO') & (df_assets['LABEL'] == label)]['REST_OBJECT_ID'].values[0]
    return int(portfolio_id)

# %% [markdown]
# Récupération de la composition d’un portefeuille :

# %%
def get_portfolio(portfolio_id):
    data = get_data('portfolio/{}/dyn_amount_compo'.format(portfolio_id))
    df_portfolio = pd.read_json(data)
    return df_portfolio

# %% [markdown]
# Get assets from portfolio :

# %%
def get_assets_portfolio(df_portfolio, date):
    if date not in df_portfolio['values']:
        return np.NaN
    return df_portfolio['values'][date]

# %% [markdown]
# MAJ de la composition d’un portefeuille :

# %%
def portfolio_json_assets(assets):
    json = ''
    for asset in assets:
        json += '{{"asset":{{"asset": {}, "quantity": {}}}}},'.format(asset["asset"]["asset"], asset["asset"]["quantity"])
    return json[:-1]
    
def seralize_portfolio_content(df_portfoliot, assets=None):
    label = df_portfoliot['label'][0]#"EPITA_PTF_10"
    currency = df_portfoliot['currency'][0]#"EUR"
    type_ = df_portfoliot['type'][0]
    date = '2016-06-01'

    if assets is None:
      res = '{{"label": "{}", "currency": {{"code": "{}"}}, "type": "{}", "values": {{}} }}'.format(label, currency, type_, date)

    else:
      assets = portfolio_json_assets(assets)
      res = '{{"label": "{}", "currency": {{"code": "{}"}}, "type": "{}", "values": {{"{}": [{}, {{"currency": {{"currency": {{"code": "EUR"}}, "amount": {} }}  }}  ]}}}}'.format(label, currency, type_, date, assets, 300)
    #res = '{{"label": "{}", "currency": {{"code": "{}"}}, "type": "{}", "values": {{ "{}": [{}] }} }}'.format(label, currency, type_, date, assets)

    return json.loads(res)

def deseralize_portfolio_content(json_portfolio):
    json_portfolio = pd.json_normalize(json_portfolio)
    
    cols = [col for col in json_portfolio.columns if col.split('.')[0] == 'values']
    json_portfolio = json_portfolio[cols]
    json_portfolio.columns = json_portfolio.columns.map(lambda x: x.split(".")[0])

    json_assets = json_portfolio['values'][0]
    assets = []
    for asset in json_assets:
        assets.append(asset)
    return assets

# %% [markdown]
# [A CHECK le JSON de put_portfolio]
#
# Ecriture dans le portefeuille

# %%
def put_portfolio(portfolio_id, df_portfolio, assets):
    content = seralize_portfolio_content(df_portfolio, assets)
    put_data('portfolio/{}/dyn_amount_compo'.format(portfolio_id), content)

# %% [markdown]
# Reset asset in portfolio :

# %%
def reset_assets_portfolio(portfolio_id, df_portfolio):
    content = seralize_portfolio_content(df_portfolio)
    content['values'] = {}
    put_data('portfolio/{}/dyn_amount_compo'.format(portfolio_id), content)

# %% [markdown]
# Contraites :
#
# 50% d'actions  (en montant pas en quantité)
#
# Le portefeuille doit être exactement composé d’un minimum de 15 actifs, et d’un maximum de 40 actifs.

# %% [markdown]
# Attention aux devises :
#
# Vérifier bien la devise dans laquelle est exprimée l’actif.
#
# Avez-vous utilisé le bon taux de conversion pour la devise ?
#
# Avez-vous utilisé le taux dans le bon sens ?

# %% [markdown]
# Attention aux quotités:
#
# Votre portefeuille comporte-il bien un nombre entier d’actif ? Ou avez-vous acheté 0.0001 action Total ?
#
# L’actif est-il achetable par unité, dizaine, centaines ? le prix donné est-il un prix par unité, dizaine, centaine ?
#
# Le prix de l’actif est-il exprimé en unité ou en centimes ?
#
# Si vous avez arrondis à postériori les quotités, respectez-vous bien toujours les normes fixées pour le portefeuille ?

# %% [markdown]
# Merge des cotations de l'asset (asset_id) le 1er jour avec les cotations du dernier jour
#
# Que faisons-nous si la date de début ou de fin de l'asset n'est pas disponible ? on prend un jour avant ? un jour après ?

# %% [markdown]
# **SELECTION DES ACTIFS POUR LE PORTFOLIO :**

# %% [markdown]
# Génération de la voile de bateau pour 10 000 portfolios composés de tous les actifs possibles et des quantités aléatoires

# %%
import matplotlib.pyplot as plt
import random
#FIXME il faudrait imposer les contraintes du sujet aux portfolios générés (ex: nav 1 et 15%, stock > 50%, ...)
def get_Markowitz_Bullet(begin_date, end_date, best_assets=None, assets=None, iterations=10000):
    if assets is None:
        assets = get_df_asset(begin_date, df_currency_rate)
        assets = assets[assets['TYPE'] != 'PORTFOLIO']
    assets_id = [int(asset_id) for asset_id in assets['ASSET_DATABASE_ID'].values]
    #assets_id = random.choices(assets_id, k=5)
    
    #dataframe de tous les ratio 12 Sharpe 13 Rendement 10 Volatile pour chaque assets
    df_ratios = get_df_ratios(assets_id, begin_date, end_date)
    assets = assets.merge(df_ratios, on='ASSET_DATABASE_ID')
    
    portfolio_returns = []
    portfolio_volatilities = []
    portfolio_sharpes = []
    
    returns = assets['rendement'].values
    volatilities = assets['volatilite'].values
    sharpes = assets['sharpe'].values
    
    for i in range(iterations):
        weights = np.random.dirichlet(np.ones(assets.shape[0]), size=1)
        weights = weights[0]

        total_returns = np.dot(returns, weights)
        total_volatilities = np.dot(volatilities, weights)
        total_sharpes = np.dot(sharpes, weights)
        
        #rates_returns = (1 + returns)**(365/1582) - 1

        #portfolio_sharpes.append((np.sum(rates_returns) - 0.05)/np.sum(total_volatilities))
        #print((np.sum(taux_returns) - 0.05)/np.sum(total_volatilities))
        #print(-(taux_returns - 0.05)/np.dot(volatilities, weights))
        
        portfolio_returns.append(total_returns)
        portfolio_volatilities.append(total_volatilities)
        portfolio_sharpes.append(total_sharpes)
        
    portfolio_returns = np.array(portfolio_returns)
    portfolio_volatilities = np.array(portfolio_volatilities)
    portfolio_sharpes = np.array(portfolio_sharpes)
    
    plt.figure(figsize=(18,15))
    plt.scatter(portfolio_volatilities, portfolio_returns, c = portfolio_returns/portfolio_volatilities)
                #c=(portfolio_sharpes)) #FIXME
    plt.xlabel('Volatility')
    plt.ylabel('Return')
    plt.colorbar(label='Sharpe ratio')
    plt.title('Markowitz Bullet (voile de bateau)')
    
    if best_assets is not None:
        returns = best_assets['rendement'].values
        volatilities = best_assets['volatilite'].values
        sharpes = best_assets['sharpe'].values
        best_weights = best_assets['weights'].values

        best_portfolio_returns = np.dot(returns, best_weights)
        best_portfolio_volatilies = np.dot(volatilities, best_weights)
        best_sharpe = best_portfolio_returns / best_portfolio_volatilies
        plt.scatter(best_portfolio_volatilies, best_portfolio_returns, c='red', marker='+', s=[500])

        print('Best portfolio have a sharpe ratio = {}'.format(best_sharpe))

#get_Markowitz_Bullet('2016-06-01', '2020-09-30')

# %%
def portfolio_stats(assets, weights):
    returns = assets['rendement'].values
    volatilities = assets['volatilite'].values
    #sharpes = assets['sharpe'].values

    total_returns = np.dot(returns, weights) #FIXME
    total_volatilities = np.dot(volatilities, weights) #FIXME

    #rates_returns = (1 + returns)**(365/1582) - 1
    #portfolio_sharpes.append((np.sum(rates_returns) - 0.05)/np.sum(total_volatilities))

    total_sharpes = total_returns / total_volatilities #FIXME
    
    return {'return': total_returns, 'volatility': total_volatilities, 'sharpe': total_sharpes}

# %% [markdown]
# Minimization Functions

# %%
def minimize_neg_sharpe(weights, assets):#on veut maximiser sharpe
    return -portfolio_stats(assets, weights)['sharpe']

# %% [markdown]
# The Optimization Function

# %%
"""def nav_max_constraint(weights): #FIXME ON doit check > 1 %
     assets = assets_global
     index_max = np.argmax(weights)
     asset_nav_max = assets['LAST_CLOSE_VALUE_IN_CURR'].values[index_max] #FIXME change close to nav
     weight_max = max(weights)
     a = weight_max * asset_nav_max - np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.095 #FIXME réduire à en-dessous de 0.10 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

     global res_nav_max
     res_nav_max = a
     return a

def nav_min_constraint(weights):
     assets = assets_global
     index_min = np.argmin(weights)
     asset_nav_min = assets['LAST_CLOSE_VALUE_IN_CURR'].values[index_min] #FIXME change close to nav
     weight_min = min(weights)
     a = weight_min * asset_nav_min - np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.015 #FIXME réduire à en-dessous de 0.10 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

     global res_nav_min
     res_nav_min = a
     return a"""

def nav_max_constraint(weights): #FIXME ON doit check > 1 %
     assets = assets_global
     nb_weights = len(weights)

     max_nav = None
     for i in range(nb_weights):
       nav = weights[i] * assets['LAST_CLOSE_VALUE_IN_CURR'].values[i]
       if max_nav is None:
         max_nav = nav
       else:
         max_nav = max(max_nav, nav)
     res = max_nav - np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.095 #FIXME réduire à en-dessous de 0.10 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

     global res_nav_max
     res_nav_max = res
     return res

def nav_min_constraint(weights):
     assets = assets_global

     nb_weights = len(weights)

     min_nav = None
     for i in range(nb_weights):
       nav = weights[i] * assets['LAST_CLOSE_VALUE_IN_CURR'].values[i]
       if min_nav is None:
         min_nav = nav
       else:
         min_nav = min(min_nav, nav)
     res = min_nav - np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.015 #FIXME réduire à en-dessous de 0.10 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

     global res_nav_min
     res_nav_min = res
     return res

def stock_constraint(weights):
     assets = assets_global

     stock_assets_id = [asset_id for asset_id in assets[assets['TYPE'] == 'STOCK'].index]
     stock_weights = weights[stock_assets_id]
     stock_nav = assets['LAST_CLOSE_VALUE_IN_CURR'].values[stock_assets_id] #FIXME close to nav

     res = np.dot(stock_weights, stock_nav) - np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.6 #FIXME augmenter au-dessus de 0.5 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

     global res_assets_number
     res_assets_number = res
     return res

def optimize_sharpe(assets):
    nb_assets = assets.shape[0]

    global assets_global
    assets_global = assets
    
    constraints = ({'type': 'eq', 'fun': nav_min_constraint},
                   {'type': 'eq', 'fun': nav_max_constraint},
                   {'type': 'eq', 'fun': stock_constraint})
    bounds = tuple((1, None) for x in range(nb_assets))
    initializer = nb_assets * [1/ nb_assets]
    
    best_sharpe = optimize.minimize(minimize_neg_sharpe, initializer, args = (assets), method='SLSQP', bounds=bounds, constraints=constraints)
    return best_sharpe.x

# %% [markdown]
# Check constraints functions

# %%
def check_nav_max_constraint(assets):
    weights = assets['weights'].values
    nb_weights = len(weights)

    max_nav = None
    for i in range(nb_weights):
      nav = weights[i] * assets['LAST_CLOSE_VALUE_IN_CURR'].values[i]
      if max_nav is None:
        max_nav = nav
      else:
        max_nav = max(max_nav, nav)
    return max_nav <= np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.10
     
def check_nav_min_constraint(assets):
    weights = assets['weights'].values
    nb_weights = len(weights)

    min_nav = None
    for i in range(nb_weights):
      nav = weights[i] * assets['LAST_CLOSE_VALUE_IN_CURR'].values[i]
      if min_nav is None:
        min_nav = nav
      else:
        min_nav = min(min_nav, nav)
    return min_nav >= np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.01 #FIXME réduire à en-dessous de 0.10 pour être large (il va converger vers 0 mais il sera jamais égale à 0)

def check_nav_constraint(assets):
     check_max = check_nav_max_constraint(assets)
     check_min = check_nav_min_constraint(assets)

     print('check_max = {}\ncheck_min = {}'.format(check_max, check_min))
     return check_max and check_min

def check_stock_constraint(assets):
     weights = assets['weights'].values

     stock_assets_index = [asset_index for asset_index in assets[assets['TYPE'] == 'STOCK'].index]
     stock_weights = weights[stock_assets_index]
     stock_nav = assets['LAST_CLOSE_VALUE_IN_CURR'].values[stock_assets_index] #FIXME close to nav

     return np.dot(stock_weights, stock_nav) >= np.dot(weights, assets['LAST_CLOSE_VALUE_IN_CURR'].values) * 0.5

def check_quantity_constraint(assets):
    for _, row in assets.iterrows():
      if ((row['MIN_BUY_AMOUNT'] is not np.NaN) and (row['weights'] < row['MIN_BUY_AMOUNT'])):
          return False
    return True

# %%
#get_Markowitz_Bullet('2016-06-01', '2020-09-30', best_assets=best_assets, iterations=100000)

# %% [markdown]
# Select best assets function :

# %%
import scipy as sp
import scipy.optimize as scopt
import scipy.stats as spstats

def select_best_assets(begin_date, end_date, df_currency_rate):
    assets = get_df_asset(begin_date, df_currency_rate)
    #remove portfolios from assets
    assets = assets[assets['TYPE'] != 'PORTFOLIO']
    assets_id = [int(asset_id) for asset_id in assets['ASSET_DATABASE_ID'].values]
    
    #dataframe de tous les ratio 12 Sharpe 13 Rendement 10 Volatile pour chaque assets
    df_ratios = get_df_ratios(assets_id, begin_date, end_date)
    assets = assets.merge(df_ratios, on='ASSET_DATABASE_ID')

    #select assets with best sharpe : #FIXME Kmeans pour la corrélation
    best_assets = assets.sort_values(by=['sharpe'], ascending=False)[:20].reset_index().drop(columns=['level_0', 'index'])#FIXME pas 20
    best_assets = best_assets[best_assets['MIN_BUY_AMOUNT'].isna()]

    global res_nav_max
    res_nav_max = 0
    global res_nav_min
    res_nav_min = 0
    global res_assets_number
    res_assets_number = 0

    weights = optimize_sharpe(best_assets)


    print(np.sort(weights))
    print('nav score max = {}'.format(res_nav_max))
    print('nav score min = {}'.format(res_nav_min))
    print('assets stock score = {}'.format(res_assets_number))

    best_assets['weights'] = (weights * 100).astype(int)
    
    print('check nav constraint : {}'.format(check_nav_constraint(best_assets)))
    print('check stock constraint : {}'.format(check_stock_constraint(best_assets)))
    print('check minimal buy amount constraint : {}'.format(check_quantity_constraint(best_assets)))

    return best_assets

# %% [markdown]
# Post best assets selected in our portfolio :

# %%
def post_assets_selected_in_portfolio(assets, begin_date, df_currency_rate):
    assets_id_quantity = [{"asset": {"asset": asset['ASSET_DATABASE_ID'], "quantity": asset['weights']}} for _, asset in assets.iterrows()]
    df_assets = df_convert_type(pd.read_json(get_data('asset/')), df_currency_rate)
    
    portfolio_id = get_portfolio_id(df_assets, 'EPITA_PTF_10')
    df_portfolio = get_portfolio(portfolio_id)
    
    reset_assets_portfolio(portfolio_id, df_portfolio)#on reset le contenu du portfolio (plus safe)
    
    df_portfolio = get_portfolio(portfolio_id)
    put_portfolio(portfolio_id, df_portfolio, assets_id_quantity)

# %% [markdown]
# Comparaison du ratio de sharpe entre notre portefeuille et le portefeuille de référence :

# %%
def compare_portfolios(our_portfolio_id, ref_portfolio_id, begin_date, end_date):    
    ratios = json.loads(post_ratio([12], [our_portfolio_id, ref_portfolio_id], begin_date, end_date))
    print('sharpe ratio in our portfolio : {}\nsharpe ratio in ref portfolio : {}'
          .format(ratios[str(our_portfolio_id)]['12']['value'], ratios[str(ref_portfolio_id)]['12']['value']))

# %% [markdown]
# Main function :

# %%
def main():
  begin_date = '2016-06-01'
  end_date = '2020-09-30'
  #df_currency_rate = getCurrencyRate()#FIXME

  assets_selected = select_best_assets(begin_date, end_date, df_currency_rate)

  post_assets_selected_in_portfolio(assets_selected, begin_date, df_currency_rate)

  df_assets = df_convert_type(pd.read_json(get_data('asset/')), df_currency_rate)

  our_portfolio_id = get_portfolio_id(df_assets, 'EPITA_PTF_10')
  our_portfolio = get_portfolio(our_portfolio_id)

  reset_assets_portfolio(our_portfolio_id, our_portfolio)#FIXME ATTENTIN A SUPRIMMER AVANT DE POST POUR AVOIR LES ACTIFS DANS LE PORTFOLIO

  our_portfolio_id = get_portfolio_id(df_assets, 'EPITA_PTF_10')
  ref_portfolio_id = get_portfolio_id(df_assets, 'REF')

  compare_portfolios(our_portfolio_id, ref_portfolio_id, begin_date, end_date)

main()
# Out:
# [1.21364362e+00 2.47505838e+00 2.76034230e+01 3.90935854e+01
#  4.45124852e+01 8.52595920e+01 9.61960720e+01 4.95887358e+02
#  6.37926335e+02 7.68860119e+02 9.74790029e+02 1.00283156e+03
#  1.05982006e+03 1.08907970e+03 2.26043193e+03 5.38644624e+03
#  7.05976951e+03 7.72439330e+03 1.47863717e+05]
# nav score max = 0.02983515601954423
# nav score min = 9.522336767986417e-07
# assets stock score = 5.739170592278242e-05
# check_max = True
# check_min = True
# check nav constraint : True
# check stock constraint : True
# check minimal buy amount constraint : True
# sharpe ratio in our portfolio : 2,737628113474
# sharpe ratio in ref portfolio : -0,337925081462

# %%
begin_date = '2016-06-01'
end_date = '2020-09-30'
assets = get_df_asset(begin_date, df_currency_rate)
assets_id = [asset_id for asset_id in assets['ASSET_DATABASE_ID'].values]

nav_values = []
for asset_id in assets_id:
  nav = get_cotation_values(asset_id, begin_date, begin_date, df_currency_rate)['nav'].values[0]
  nav_values.append(nav)

nav_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'nav'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-f747c7cb813d> in <module>()
#       6 nav_values = []
#       7 for asset_id in assets_id:
# ----> 8   nav = get_cotation_values(asset_id, begin_date, begin_date, df_currency_rate)['nav'].values[0]
#       9   nav_values.append(nav)
#      10
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/numeric.py in get_loc(self, key, method, tolerance)
#     422             return nan_idxs
#     423
# --> 424         return super().get_loc(key, method=method, tolerance=tolerance)
#     425
#     426     @cache_readonly
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'nav'

# %%
get_cotation_values(1845, begin_date, '2020-09-30', df_currency_rate)
# Out:
#             date              nav            gross    volume    high  \
# 0     2016-06-01  36.851000000000  36.851000000000  143199.0  37.125
# 1     2016-06-02  36.900000000000  36.900000000000  147480.0  37.145
# 2     2016-06-03  36.052000000000  36.052000000000  190934.0  37.200
# 3     2016-06-06  36.540000000000  36.540000000000   82279.0  36.775
# 4     2016-06-07  37.246000000000  37.246000000000  119105.0  37.347
# ...          ...              ...              ...       ...     ...
# 1116  2020-09-24  27.091248954261  27.091248954261       NaN     NaN
# 1117  2020-09-25  26.877384954417  26.877384954417       NaN     NaN
# 1118  2020-09-28  26.634573242213  26.634573242213       NaN     NaN
# 1119  2020-09-29  26.368478372669  26.368478372669       NaN     NaN
# 1120  2020-09-30  25.845002717853  25.845002717853       NaN     NaN
#
#       real_close_price  feed_source     low     ask  asset              pl  \
# 0      36.851000000000        -10.0  36.675  36.799   1845  0.037000000000
# 1      36.900000000000        -10.0  36.594  36.999   1845  0.049000000000
# 2      36.052000000000        -10.0  35.800  36.277   1845 -0.848000000000
# 3      36.540000000000        -10.0  36.082  36.587   1845  0.488000000000
# 4      37.246000000000        -10.0  36.470  37.172   1845  0.706000000000
# ...                ...          ...     ...     ...    ...             ...
# 1116   27.091248954261        -10.0     NaN     NaN   1845 -0.550081510430
# 1117   26.877384954417        -10.0     NaN     NaN   1845 -0.213863999844
# 1118   26.634573242213        -10.0     NaN     NaN   1845 -0.242811712203
# 1119   26.368478372669        -10.0     NaN     NaN   1845 -0.266094869544
# 1120   25.845002717853        -10.0     NaN     NaN   1845 -0.523475654817
#
#          bid            close          return    open
# 0     36.723  36.851000000000  0.001005052426  36.745
# 1     36.946  36.900000000000  0.001329678978  36.786
# 2     36.219  36.052000000000 -0.022981029810  36.900
# 3     36.534  36.540000000000  0.013536003550  36.190
# 4     37.150  37.246000000000  0.019321291735  36.590
# ...      ...              ...             ...     ...
# 1116     NaN  27.091248954261 -0.019900688613     NaN
# 1117     NaN  26.877384954417 -0.007894209684     NaN
# 1118     NaN  26.634573242213 -0.009034052703     NaN
# 1119     NaN  26.368478372669 -0.009990581307     NaN
# 1120     NaN  25.845002717853 -0.019852326987     NaN
#
# [1121 rows x 15 columns]

# %%
data = get_data('asset/')
df = pd.read_json(data)
df_assets = df_convert_type(df, df_currency_rate)
df_assets
# Out:
#                                    SECTOR             LIQUIDITY_ALGO  \
# 0              Télécommunications mobiles  UseGridLiquidityAlgorithm
# 1                                  Médias   PerVolLiquidityAlgorithm
# 2    Instruments de placement hors action   PerVolLiquidityAlgorithm
# 3    Instruments de placement hors action   PerVolLiquidityAlgorithm
# 4    Instruments de placement hors action   PerVolLiquidityAlgorithm
# ..                                    ...                        ...
# 475                                 Mines   PerVolLiquidityAlgorithm
# 476   Logiciels et services informatiques   PerVolLiquidityAlgorithm
# 477                                 Mines   PerVolLiquidityAlgorithm
# 478           Pharmacie et biotechnologie   PerVolLiquidityAlgorithm
# 479                     Produits ménagers   PerVolLiquidityAlgorithm
#
#     MARKET_PLACE_CITY     MARKET_PLACE_TYPE  \
# 0           FRANCFORT     Marché réglementé
# 1               PARIS     Marché réglementé
# 2                 NaN  Sans place de marché
# 3                 NaN  Sans place de marché
# 4                 NaN  Sans place de marché
# ..                ...                   ...
# 475         FRANCFORT     Marché réglementé
# 476             PARIS     Marché réglementé
# 477             PARIS     Marché réglementé
# 478          NEW YORK     Marché réglementé
# 479         FRANCFORT     Marché réglementé
#
#                                  SUP_SECTOR  VL_DELAY CODE_CIC  INDEXED_RATE  \
# 0                        Télécommunications         1     DE31           0.0
# 1                                    Médias         1     FR31           0.0
# 2                       Services financiers         1     XL41           0.0
# 3                       Services financiers         1     XL41           0.0
# 4                       Services financiers         1     XL44           0.0
# ..                                      ...       ...      ...           ...
# 475                      Matières premières         1     CA31           0.0
# 476                             Technologie         1     FR31           0.0
# 477                      Matières premières         1     ZM31           0.0
# 478                                   Santé         1     US31           0.0
# 479  Produits ménagers et de soin personnel         1     DE31           0.0
#
#     COUNTRY_CIC  IS_EURONEXT  PORT_CONTENT_COUNT  LAST_CLOSE_VALUE_IN_CURR  \
# 0     Allemagne        False                   0           26.158358284815
# 1        France         True                   0           28.129136522277
# 2    Not Listed        False                   0           82.928847761071
# 3    Not Listed        False                   0           42.844024261715
# 4    Not Listed        False                   0            5.624308945175
# ..          ...          ...                 ...                       ...
# 475      Canada        False                   0            1.270803801271
# 476      France         True                   0            0.877757493680
# 477      Zambie         True                   0            1.442269498359
# 478         USA        False                   0           77.347902574655
# 479   Allemagne        False                   0          102.652668088854
#
#      FLOATING_VALUE CREATION_DATE        SUB_TYPE IS_STRUCTURED_PRODUCT  \
# 0         0.2654572    2019-10-02  ORDINARY_STOCK                 False
# 1         0.9985230    2019-10-02  ORDINARY_STOCK                 False
# 2               NaN    2019-10-02           OPCVM                 False
# 3               NaN    2019-10-02           OPCVM                 False
# 4               NaN    2019-10-02           OPCVM                 False
# ..              ...           ...             ...                   ...
# 475       0.9970650    2019-10-02  ORDINARY_STOCK                 False
# 476       0.6407790    2019-10-02  ORDINARY_STOCK                 False
# 477       0.4446750    2019-10-02  ORDINARY_STOCK                 False
# 478       0.9161800    2019-10-02  ORDINARY_STOCK                 False
# 479       0.5141880    2019-10-02  ORDINARY_STOCK                 False
#
#      IS_ACCESSIBILITY_PUBLIC  IS_FUND_SAVE_SENS  PORT_LINE_COUNT  \
# 0                       True              False              0.0
# 1                       True              False              0.0
# 2                       True              False              0.0
# 3                       True              False              0.0
# 4                       True              False              0.0
# ..                       ...                ...              ...
# 475                     True              False              0.0
# 476                     True              False              0.0
# 477                     True              False              0.0
# 478                     True              False              0.0
# 479                     True              False              0.0
#
#      ASSET_DATABASE_ID            ASSET PRICE MODE  \
# 0                 1845  Par Défaut (configuration)
# 1                 1846  Par Défaut (configuration)
# 2                 2122  Par Défaut (configuration)
# 3                 2123  Par Défaut (configuration)
# 4                 2124  Par Défaut (configuration)
# ..                 ...                         ...
# 475               1879  Par Défaut (configuration)
# 476               1997  Par Défaut (configuration)
# 477               1991  Par Défaut (configuration)
# 478               2106  Par Défaut (configuration)
# 479               1984  Par Défaut (configuration)
#
#                         GICS_SUB_INDUSTRY  MARKET_PLACE_TELEKURS  \
# 0    Services de Télécommunication Mobile                   44.0
# 1                               Publicité                   25.0
# 2                                     NaN                    NaN
# 3                                     NaN                    NaN
# 4                                     NaN                    NaN
# ..                                    ...                    ...
# 475                                    Or                   44.0
# 476                Services d'Aide Divers                   25.0
# 477        Métaux et Minéraux Diversifiés                   25.0
# 478              Produits Pharmaceutiques                   65.0
# 479          Vente au Détail sur Internet                   44.0
#
#         ISIN_CODE  IS_EUROLAND      MARKET_PLACE  \
# 0    DE0005545503         True  FRANCFORT (XETR)
# 1    FR0010285965         True      PARIS (XPAR)
# 2    FR0010626796         True          No Place
# 3    FR0007057435         True          No Place
# 4    FR0007040373         True          No Place
# ..            ...          ...               ...
# 475  CA98462Y1007         True  FRANCFORT (XETR)
# 476  FR0011471291         True      PARIS (XPAR)
# 477  ZM0000000037         True      PARIS (XPAR)
# 478  US98978V1035        False   NEW YORK (XNYS)
# 479  DE0005111702         True  FRANCFORT (XETR)
#
#                                        GRAPH_LAST_YEAR  \
# 0    com.jump.framework.gui.painter.PreviewGraphDat...
# 1    com.jump.framework.gui.painter.PreviewGraphDat...
# 2    com.jump.framework.gui.painter.PreviewGraphDat...
# 3    com.jump.framework.gui.painter.PreviewGraphDat...
# 4    com.jump.framework.gui.painter.PreviewGraphDat...
# ..                                                 ...
# 475  com.jump.framework.gui.painter.PreviewGraphDat...
# 476  com.jump.framework.gui.painter.PreviewGraphDat...
# 477  com.jump.framework.gui.painter.PreviewGraphDat...
# 478  com.jump.framework.gui.painter.PreviewGraphDat...
# 479  com.jump.framework.gui.painter.PreviewGraphDat...
#
#      PAY_ACCOUNT_ON_DEFAULT  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 475                   False
# 476                   False
# 477                   False
# 478                   False
# 479                   False
#
#                                        GRAPH_PAST_WEEK  \
# 0    com.jump.framework.gui.painter.PreviewGraphDat...
# 1    com.jump.framework.gui.painter.PreviewGraphDat...
# 2    com.jump.framework.gui.painter.PreviewGraphDat...
# 3    com.jump.framework.gui.painter.PreviewGraphDat...
# 4    com.jump.framework.gui.painter.PreviewGraphDat...
# ..                                                 ...
# 475  com.jump.framework.gui.painter.PreviewGraphDat...
# 476  com.jump.framework.gui.painter.PreviewGraphDat...
# 477  com.jump.framework.gui.painter.PreviewGraphDat...
# 478  com.jump.framework.gui.painter.PreviewGraphDat...
# 479  com.jump.framework.gui.painter.PreviewGraphDat...
#
#                       GICS_SECTOR MARKET_PLACE_CURRENCY  \
# 0       Services de Communication                   EUR
# 1    Consommation Discrétionnaire                   EUR
# 2                             NaN                   EUR
# 3                             NaN                   EUR
# 4                             NaN                   EUR
# ..                            ...                   ...
# 475                     Matériaux                   EUR
# 476                     Industrie                   EUR
# 477                     Matériaux                   EUR
# 478                         Santé                   USD
# 479  Consommation Discrétionnaire                   EUR
#
#                                     GRAPH_LAST_6_MONTH  \
# 0    com.jump.framework.gui.painter.PreviewGraphDat...
# 1    com.jump.framework.gui.painter.PreviewGraphDat...
# 2    com.jump.framework.gui.painter.PreviewGraphDat...
# 3    com.jump.framework.gui.painter.PreviewGraphDat...
# 4    com.jump.framework.gui.painter.PreviewGraphDat...
# ..                                                 ...
# 475  com.jump.framework.gui.painter.PreviewGraphDat...
# 476  com.jump.framework.gui.painter.PreviewGraphDat...
# 477  com.jump.framework.gui.painter.PreviewGraphDat...
# 478  com.jump.framework.gui.painter.PreviewGraphDat...
# 479  com.jump.framework.gui.painter.PreviewGraphDat...
#
#     asset_custom_classification_bloomberg LAST_QUOTE_SOURCE MARKET_PLACE_MIC  \
# 0                                   asset           Importé             XETR
# 1                                   asset           Importé             XPAR
# 2                                   asset           Importé              NaN
# 3                                   asset           Importé              NaN
# 4                                   asset           Importé              NaN
# ..                                    ...               ...              ...
# 475                                 asset           Importé             XETR
# 476                                 asset           Importé             XPAR
# 477                                 asset           Importé             XPAR
# 478                                 asset           Importé             XNYS
# 479                                 asset           Importé             XETR
#
#                             GICS_INDUSTRY  IS_DEPOSITARY_QUOTES  \
# 0    Services de Télécommunication Mobile                 False
# 1                                  Médias                 False
# 2                                     NaN                 False
# 3                                     NaN                 False
# 4                                     NaN                 False
# ..                                    ...                   ...
# 475                    Métaux et Minéraux                 False
# 476              Services aux Entreprises                 False
# 477                    Métaux et Minéraux                 False
# 478              Produits Pharmaceutiques                 False
# 479              Vente par correspondance                 False
#
#     CITY_OR_ACRONYM_OR_NAME  DAILY_PRICE_COUNT              MODIFICATION_DATE  \
# 0                 FRANCFORT               1898  2019-10-02T15:11:31.000+02:00
# 1                     PARIS               1904  2019-10-02T15:11:31.000+02:00
# 2                  no_place               1872  2019-10-02T15:11:31.000+02:00
# 3                  no_place               1853  2019-10-02T15:11:31.000+02:00
# 4                  no_place                525  2019-10-02T15:11:31.000+02:00
# ..                      ...                ...                            ...
# 475               FRANCFORT               1897  2019-10-02T15:11:31.000+02:00
# 476                   PARIS               1904  2019-10-02T15:11:31.000+02:00
# 477                   PARIS               1747  2019-10-02T15:11:31.000+02:00
# 478                NEW YORK               1883  2019-10-02T15:11:31.000+02:00
# 479               FRANCFORT               1890  2019-10-02T15:11:31.000+02:00
#
#            SUB_CATEGORY_CIC  FINAL_UNDERLYING  IS_COMPOSITE  \
# 0             Common equity              1845         False
# 1             Common equity              1846         False
# 2              Equity funds              2122         False
# 3              Equity funds              2123         False
# 4    Asset allocation funds              2124         False
# ..                      ...               ...           ...
# 475           Common equity              1879         False
# 476           Common equity              1997         False
# 477           Common equity              1991         False
# 478           Common equity              2106         False
# 479           Common equity              1984         False
#
#     REST_UNIQUE_NUMBER  UNDERLYING_OR_ASSET_IF_UNDERLYING_NOT_AVAILABLE  \
# 0                 1845                                             1845
# 1                 1846                                             1846
# 2                 2122                                             2122
# 3                 2123                                             2123
# 4                 2124                                             2124
# ..                 ...                                              ...
# 475               1879                                             1879
# 476               1997                                             1997
# 477               1991                                             1991
# 478               2106                                             2106
# 479               1984                                             1984
#
#     MARKET_PLACE_COUNTRY     BLOOMBERG_CODE  \
# 0              Allemagne      DRI GY EQUITY
# 1                 France    ALMIL FP EQUITY
# 2                    NaN  VEGCEQD FP EQUITY
# 3                    NaN  SGPPEA2 FP EQUITY
# 4                    NaN  SGPRIV1 FP EQUITY
# ..                   ...                ...
# 475            Allemagne      RNY GR EQUITY
# 476               France    MAGIS FP EQUITY
# 477               France    MLZAM FP EQUITY
# 478                  USA      ZTS US EQUITY
# 479            Allemagne      ZO1 GY EQUITY
#
#                                    GICS_INDUSTRY_GROUP quote_value_type  \
# 0                                   Télécommunications           Défaut
# 1                                               Médias           Défaut
# 2                                                  NaN           Défaut
# 3                                                  NaN           Défaut
# 4                                                  NaN           Défaut
# ..                                                 ...              ...
# 475                                          Matériaux           Défaut
# 476             Services Commerciaux et Professionnels           Défaut
# 477                                          Matériaux           Défaut
# 478  Sciences Pharmaceutiques, Biotechnologiques et...           Défaut
# 479                                       Distribution           Défaut
#
#     CURRENCY                             LABEL              INDUSTRY  \
# 0        EUR                  1&1 DRILLISCH AG              Télécom.
# 1        EUR                        1000MERCIS   Services aux conso.
# 2        EUR                  1818-VEGA EUR CO  Sociétés financières
# 3        EUR  29 HAUSSMANN CROISSANCE EUROPE D  Sociétés financières
# 4        EUR            29 HAUSSMANN EQUILIBRE  Sociétés financières
# ..       ...                               ...                   ...
# 475      EUR                   YAMANA GOLD INC     Matériaux de base
# 476      EUR                         YMAGIS SA           Technologie
# 477      EUR                ZCCM INVESTMEN - B     Matériaux de base
# 478      USD                        ZOETIS INC                 Santé
# 479      EUR                        ZOOPLUS AG       Biens de conso.
#
#      LAST_CLOSE_VALUE  IS_FUND_FED        LAST_QUOTES_UPDATE_DATE  \
# 0     26.158358284815        False  2020-10-23T11:48:37.000+02:00
# 1     28.129136522277        False  2020-10-23T11:48:37.000+02:00
# 2     82.928847761071        False  2020-10-23T15:49:55.000+02:00
# 3     42.844024261715        False  2020-10-23T15:59:34.000+02:00
# 4      5.624308945175        False  2020-10-23T16:01:42.000+02:00
# ..                ...          ...                            ...
# 475    1.270803801271        False  2020-10-23T11:49:15.000+02:00
# 476    0.877757493680        False  2020-10-23T15:10:49.000+02:00
# 477    1.442269498359        False  2020-10-23T11:55:31.000+02:00
# 478   77.347902574655        False  2020-10-23T11:45:19.000+02:00
# 479  102.652668088854        False  2020-10-23T11:55:19.000+02:00
#
#      LAST_GROSS_VALUE  BLOOMBERG_ID    MARKET_CAP_CATEGORY ASSET_STATUS  \
# 0     26.158358284815  BBG000BD8RR1  Autre que des actions       normal
# 1     28.129136522277  BBG000M1HS93  Autre que des actions       normal
# 2     82.928847761071  BBG000NBHV66  Autre que des actions       normal
# 3     42.844024261715  BBG000Q6B219  Autre que des actions       normal
# 4      5.624308945175  BBG000NFZ9R3  Autre que des actions       normal
# ..                ...           ...                    ...          ...
# 475    1.270803801271  BBG000PNFRV1  Autre que des actions       normal
# 476    0.877757493680  BBG004G41X01  Autre que des actions       normal
# 477    1.442269498359  BBG000BN2FR1  Autre que des actions       normal
# 478   77.347902574655  BBG0039320N9  Autre que des actions       normal
# 479  102.652668088854  BBG000D2ZJN5  Autre que des actions       normal
#
#     FINAL_UNDERLYING_TYPE MARKET_PLACE_OR_ASSET_COUNTRY      CATEGORY_CIC  \
# 0                   STOCK                     Allemagne            Equity
# 1                   STOCK                        France            Equity
# 2                    FUND                        France  Investment funds
# 3                    FUND                        France  Investment funds
# 4                    FUND                        France  Investment funds
# ..                    ...                           ...               ...
# 475                 STOCK                     Allemagne            Equity
# 476                 STOCK                        France            Equity
# 477                 STOCK                        France            Equity
# 478                 STOCK                           USA            Equity
# 479                 STOCK                     Allemagne            Equity
#
#     REST_OBJECT_ID                                    GRAPH_PAST_YEAR  \
# 0             1845  com.jump.framework.gui.painter.PreviewGraphDat...
# 1             1846  com.jump.framework.gui.painter.PreviewGraphDat...
# 2             2122  com.jump.framework.gui.painter.PreviewGraphDat...
# 3             2123  com.jump.framework.gui.painter.PreviewGraphDat...
# 4             2124  com.jump.framework.gui.painter.PreviewGraphDat...
# ..             ...                                                ...
# 475           1879  com.jump.framework.gui.painter.PreviewGraphDat...
# 476           1997  com.jump.framework.gui.painter.PreviewGraphDat...
# 477           1991  com.jump.framework.gui.painter.PreviewGraphDat...
# 478           2106  com.jump.framework.gui.painter.PreviewGraphDat...
# 479           1984  com.jump.framework.gui.painter.PreviewGraphDat...
#
#                                           GRAPH_PERIOD LAST_QUOTE_DATE  \
# 0    com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 1    com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 2    com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 3    com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 4    com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# ..                                                 ...             ...
# 475  com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 476  com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 477  com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 478  com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
# 479  com.jump.framework.gui.painter.PreviewGraphDat...      2020-10-23
#
#                                 SUB_SECTOR STOCK_TYPE GLOBAL_TYPE  \
# 0               Télécommunications mobiles  Ordinaire       Actif
# 1                         Agence de médias  Ordinaire       Actif
# 2    Instruments de placement hors actions        NaN       Actif
# 3    Instruments de placement hors actions        NaN       Actif
# 4    Instruments de placement hors actions        NaN       Actif
# ..                                     ...        ...         ...
# 475                        Mines aurifères  Ordinaire       Actif
# 476                 Services informatiques  Ordinaire       Actif
# 477           Activités minières générales  Ordinaire       Actif
# 478                              Pharmacie  Ordinaire       Actif
# 479             Produits ménagers durables  Ordinaire       Actif
#
#      IS_PUBLICLY_TRADED SEDOL_CODE               MARKET_PLACE_DESC  \
# 0                  True    5734672                           XETRA
# 1                  True    B0XHV59  NYSE EURONEXT - EURONEXT PARIS
# 2                  True        NaN                        No Place
# 3                  True        NaN                        No Place
# 4                  True        NaN                        No Place
# ..                  ...        ...                             ...
# 475                True    B00X473                           XETRA
# 476                True    B941H00  NYSE EURONEXT - EURONEXT PARIS
# 477                True    5013508  NYSE EURONEXT - EURONEXT PARIS
# 478                True    B95WG16   NEW YORK STOCK EXCHANGE, INC.
# 479                True    B2R9XL5                           XETRA
#
#     ASSET_OR_MARKET_PLACE_COUNTRY QUOTE_TYPE EMIR_CLEARING_ID_TYPE   TYPE  \
# 0                       Allemagne      value                   LEI  STOCK
# 1                          France      value                   LEI  STOCK
# 2                          France      value                   LEI   FUND
# 3                          France      value                   LEI   FUND
# 4                          France      value                   LEI   FUND
# ..                            ...        ...                   ...    ...
# 475                        Canada      value                   LEI  STOCK
# 476                        France      value                   LEI  STOCK
# 477                        Zambie      value                   LEI  STOCK
# 478                           USA      value                   LEI  STOCK
# 479                     Allemagne      value                   LEI  STOCK
#
#        COUNTRY asset_attr_init FIRST_QUOTE_DATE  IS_PORTFOLIO COUNTRY_ISO_3  \
# 0    Allemagne        a garder       2013-06-03         False           DEU
# 1       France        a garder       2013-06-03         False           FRA
# 2       France             NaN       2013-06-03         False           FRA
# 3       France             NaN       2013-06-03         False           FRA
# 4       France             NaN       2018-10-22         False           FRA
# ..         ...             ...              ...           ...           ...
# 475     Canada        a garder       2013-06-03         False           CAN
# 476     France        a garder       2013-06-03         False           FRA
# 477     Zambie        a garder       2013-06-03         False           ZMB
# 478        USA        a garder       2013-06-03         False           USA
# 479  Allemagne        a garder       2013-06-03         False           DEU
#
#     asset_custom_classification_Tab. de bord GSM ASSET_MARKET_SUB_GROUP  \
# 0                                          STOCK                    NaN
# 1                                          STOCK        Euronext Growth
# 2                                           FUND                    NaN
# 3                                           FUND                    NaN
# 4                                           FUND                    NaN
# ..                                           ...                    ...
# 475                                        STOCK                    NaN
# 476                                        STOCK   Reg. Mkt - Segment C
# 477                                        STOCK        Euronext Access
# 478                                        STOCK                    NaN
# 479                                        STOCK                    NaN
#
#     ELIGIBLE_PEA_PME ELIGIBLE_PEA IS_REAL_ESTATE_FUND  \
# 0                NaN          NaN                 NaN
# 1               True         True                 NaN
# 2               True         True               False
# 3               True         True               False
# 4               True        False               False
# ..               ...          ...                 ...
# 475              NaN          NaN                 NaN
# 476             True         True                 NaN
# 477              NaN          NaN                 NaN
# 478              NaN          NaN                 NaN
# 479            False         True                 NaN
#
#     asset_fund_info_isin_code asset_fund_info_objective_long  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                FR0010626796                Multiple Region
# 3                FR0007057435                 European Union
# 4                FR0007040373            Moderate Allocation
# ..                        ...                            ...
# 475                       NaN                            NaN
# 476                       NaN                            NaN
# 477                       NaN                            NaN
# 478                       NaN                            NaN
# 479                       NaN                            NaN
#
#     asset_fund_info_cut_off                   asset_fund_info_administrator  \
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2              11:45:00.000                   CACEIS Fund Administration SA
# 3              18:00:00.000  Societe Generale Securities Services France SA
# 4              18:00:00.000  Societe Generale Securities Services France SA
# ..                      ...                                             ...
# 475                     NaN                                             NaN
# 476                     NaN                                             NaN
# 477                     NaN                                             NaN
# 478                     NaN                                             NaN
# 479                     NaN                                             NaN
#
#      asset_fund_info_manager_stated_perf_fee  \
# 0                                        NaN
# 1                                        NaN
# 2                                        0.2
# 3                                        0.0
# 4                                        0.0
# ..                                       ...
# 475                                      NaN
# 476                                      NaN
# 477                                      NaN
# 478                                      NaN
# 479                                      NaN
#
#     asset_fund_info_authorized_for_retail_investors  \
# 0                                               NaN
# 1                                               NaN
# 2                                             False
# 3                                             False
# 4                                             False
# ..                                              ...
# 475                                             NaN
# 476                                             NaN
# 477                                             NaN
# 478                                             NaN
# 479                                             NaN
#
#     BOND_CREDIT_RISK_COMPUTATION_MODE       FUND_TYPE  \
# 0                                 NaN             NaN
# 1                                 NaN             NaN
# 2                          Par défaut  Fonds de fonds
# 3                          Par défaut             FCP
# 4                          Par défaut             FCP
# ..                                ...             ...
# 475                               NaN             NaN
# 476                               NaN             NaN
# 477                               NaN             NaN
# 478                               NaN             NaN
# 479                               NaN             NaN
#
#     asset_fund_info_creation_date  \
# 0                             NaN
# 1                             NaN
# 2                      1997-02-18
# 3                      2001-04-06
# 4                      2000-01-14
# ..                            ...
# 475                           NaN
# 476                           NaN
# 477                           NaN
# 478                           NaN
# 479                           NaN
#
#                                asset_fund_info_vl_date  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Journalière(Tous) - (Français (France)/0/Aucun...
# 3    Journalière(Tous) - (Français (France)/0/Aucun...
# 4    Journalière(Tous) - (Français (France)/0/Aucun...
# ..                                                 ...
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
# 479                                                NaN
#
#     asset_fund_info_is_feeded asset_fund_info_is_euro_ucits  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                       False                          True
# 3                       False                          True
# 4                       False                         False
# ..                        ...                           ...
# 475                       NaN                           NaN
# 476                       NaN                           NaN
# 477                       NaN                           NaN
# 478                       NaN                           NaN
# 479                       NaN                           NaN
#
#     asset_fund_info_asset_class_focus  asset_fund_info_maximum_front_end_fee  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                              Action                                   0.04
# 3                              Action                                   0.01
# 4                    Mixed Allocation                                   0.05
# ..                                ...                                    ...
# 475                               NaN                                    NaN
# 476                               NaN                                    NaN
# 477                               NaN                                    NaN
# 478                               NaN                                    NaN
# 479                               NaN                                    NaN
#
#     TRANSPARENCY_LIST asset_fund_info_strategy BOND_WAL_COMPUTATION_MODE  \
# 0                 NaN                      NaN                       NaN
# 1                 NaN                      NaN                       NaN
# 2                                        Blend                Par défaut
# 3                                        Blend                Par défaut
# 4                          Moderate Allocation                Par défaut
# ..                ...                      ...                       ...
# 475               NaN                      NaN                       NaN
# 476               NaN                      NaN                       NaN
# 477               NaN                      NaN                       NaN
# 478               NaN                      NaN                       NaN
# 479               NaN                      NaN                       NaN
#
#      asset_fund_info_manager_stated_fee  \
# 0                                   NaN
# 1                                   NaN
# 2                                 0.020
# 3                                 0.024
# 4                                 0.024
# ..                                  ...
# 475                                 NaN
# 476                                 NaN
# 477                                 NaN
# 478                                 NaN
# 479                                 NaN
#
#     asset_fund_info_valorisation_frequency BOND_RISK_COMPUTATION_MODE  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                              Journalière                 Par défaut
# 3                              Journalière                 Par défaut
# 4                              Journalière                 Par défaut
# ..                                     ...                        ...
# 475                                    NaN                        NaN
# 476                                    NaN                        NaN
# 477                                    NaN                        NaN
# 478                                    NaN                        NaN
# 479                                    NaN                        NaN
#
#     BOND_WAM_COMPUTATION_MODE asset_fund_info_auditor  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                  Par défaut    Conseils Associes SA
# 3                  Par défaut                     NaN
# 4                  Par défaut                     NaN
# ..                        ...                     ...
# 475                       NaN                     NaN
# 476                       NaN                     NaN
# 477                       NaN                     NaN
# 478                       NaN                     NaN
# 479                       NaN                     NaN
#
#     asset_fund_info_fund_leverage  asset_fund_info_maximum_back_end_fee  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                           False                                   0.0
# 3                           False                                   0.0
# 4                           False                                   0.0
# ..                            ...                                   ...
# 475                           NaN                                   NaN
# 476                           NaN                                   NaN
# 477                           NaN                                   NaN
# 478                           NaN                                   NaN
# 479                           NaN                                   NaN
#
#     BOND_YTM_COMPUTATION_MODE asset_fund_info_fund_type  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                  Par défaut            Fonds de fonds
# 3                  Par défaut                       FCP
# 4                  Par défaut                       FCP
# ..                        ...                       ...
# 475                       NaN                       NaN
# 476                       NaN                       NaN
# 477                       NaN                       NaN
# 478                       NaN                       NaN
# 479                       NaN                       NaN
#
#      asset_fund_info_minimum_investment_shares  \
# 0                                          NaN
# 1                                          NaN
# 2                                          1.0
# 3                                          NaN
# 4                                          1.0
# ..                                         ...
# 475                                        NaN
# 476                                        NaN
# 477                                        NaN
# 478                                        NaN
# 479                                        NaN
#
#     asset_fund_info_bloomberg_ticker      asset_fund_info_company  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                  VEGCEQD FP EQUITY  Vega Investment Managers SA
# 3                  SGPPEA2 FP EQUITY         SG 29 Haussmann SASU
# 4                  SGPRIV1 FP EQUITY         SG 29 Haussmann SASU
# ..                               ...                          ...
# 475                              NaN                          NaN
# 476                              NaN                          NaN
# 477                              NaN                          NaN
# 478                              NaN                          NaN
# 479                              NaN                          NaN
#
#     asset_fund_info_depositary  MIN_BUY_AMOUNT  \
# 0                          NaN             NaN
# 1                          NaN             NaN
# 2               CACEIS Bank SA             NaN
# 3          Societe Generale SA             0.0
# 4          Societe Generale SA             0.0
# ..                         ...             ...
# 475                        NaN             NaN
# 476                        NaN             NaN
# 477                        NaN             NaN
# 478                        NaN             NaN
# 479                        NaN             NaN
#
#      asset_fund_info_subscription_committee  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                      0.01
# 4                                       NaN
# ..                                      ...
# 475                                     NaN
# 476                                     NaN
# 477                                     NaN
# 478                                     NaN
# 479                                     NaN
#
#     asset_fund_info_geographical_focus  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                     Union européenne
# 4                            Pays OCDE
# ..                                 ...
# 475                                NaN
# 476                                NaN
# 477                                NaN
# 478                                NaN
# 479                                NaN
#
#                            asset_fund_info_day_cut_off  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Journalière(Tous) - (Français (France)/0/Aucun...
# 4    Journalière(Tous) - (Français (France)/0/Aucun...
# ..                                                 ...
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
# 479                                                NaN
#
#      asset_fund_info_minimum_subscription  MIN_BUY_INITIAL_AMOUNT  \
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                                     NaN                     NaN
# 3                                     0.0                     0.0
# 4                                     0.0                     0.0
# ..                                    ...                     ...
# 475                                   NaN                     NaN
# 476                                   NaN                     NaN
# 477                                   NaN                     NaN
# 478                                   NaN                     NaN
# 479                                   NaN                     NaN
#
#     asset_fund_info_vl_known  asset_fund_info_pct_max_opcvm  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                      False                            0.1
# 4                      False                            0.5
# ..                       ...                            ...
# 475                      NaN                            NaN
# 476                      NaN                            NaN
# 477                      NaN                            NaN
# 478                      NaN                            NaN
# 479                      NaN                            NaN
#
#      asset_fund_info_initial_minimum_subscription  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             0.0
# 4                                             0.0
# ..                                            ...
# 475                                           NaN
# 476                                           NaN
# 477                                           NaN
# 478                                           NaN
# 479                                           NaN
#
#     asset_fund_info_fund_open_pymt_shr asset_fund_info_amf_date  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                               Income               2001-03-22
# 4                         Accumulation               1999-12-28
# ..                                 ...                      ...
# 475                                NaN                      NaN
# 476                                NaN                      NaN
# 477                                NaN                      NaN
# 478                                NaN                      NaN
# 479                                NaN                      NaN
#
#      asset_fund_info_decimalisation      asset_fund_info_amf_classification  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               3.0  Actions des pays de l'Union Européenne
# 4                               3.0                             Diversifiés
# ..                              ...                                     ...
# 475                             NaN                                     NaN
# 476                             NaN                                     NaN
# 477                             NaN                                     NaN
# 478                             NaN                                     NaN
# 479                             NaN                                     NaN
#
#     asset_fund_info_abide_with_the_four_criterias  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                            True
# ..                                            ...
# 475                                           NaN
# 476                                           NaN
# 477                                           NaN
# 478                                           NaN
# 479                                           NaN
#
#     asset_fund_info_reuters_code REUTERS_CODE  \
# 0                            NaN          NaN
# 1                            NaN          NaN
# 2                            NaN          NaN
# 3                            NaN          NaN
# 4                            NaN          NaN
# ..                           ...          ...
# 475                          NaN          NaN
# 476                          NaN          NaN
# 477                          NaN          NaN
# 478                          NaN          NaN
# 479                          NaN          NaN
#
#     asset_fund_info_subscription_frequency  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 475                                    NaN
# 476                                    NaN
# 477                                    NaN
# 478                                    NaN
# 479                                    NaN
#
#     asset_fund_info_redemption_frequency VALOREN_CODE  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                    NaN          NaN
# 4                                    NaN          NaN
# ..                                   ...          ...
# 475                                  NaN          NaN
# 476                                  NaN          NaN
# 477                                  NaN          NaN
# 478                                  NaN          NaN
# 479                                  NaN          NaN
#
#     asset_fund_info_valoren_code asset_fund_info_manager  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ..                           ...                     ...
# 475                          NaN                     NaN
# 476                          NaN                     NaN
# 477                          NaN                     NaN
# 478                          NaN                     NaN
# 479                          NaN                     NaN
#
#      asset_fund_info_redemption_committee asset_fund_info_advised_horizon  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ..                                    ...                             ...
# 475                                   NaN                             NaN
# 476                                   NaN                             NaN
# 477                                   NaN                             NaN
# 478                                   NaN                             NaN
# 479                                   NaN                             NaN
#
#      FUND_REF_IDX asset_fund_info_comanager HAS_TOBIN_TAX CUSIP_CODE  \
# 0             NaN                       NaN           NaN        NaN
# 1             NaN                       NaN           NaN        NaN
# 2             NaN                       NaN           NaN        NaN
# 3             NaN                       NaN           NaN        NaN
# 4             NaN                       NaN           NaN        NaN
# ..            ...                       ...           ...        ...
# 475           NaN                       NaN           NaN  98462Y100
# 476           NaN                       NaN           NaN        NaN
# 477           NaN                       NaN           NaN        NaN
# 478           NaN                       NaN           NaN  98978V103
# 479           NaN                       NaN           NaN        NaN
#
#     LOCAL_CODE  asset_fund_info_rate_entry_sdg  \
# 0          NaN                             NaN
# 1          NaN                             NaN
# 2          NaN                             NaN
# 3          NaN                             NaN
# 4          NaN                             NaN
# ..         ...                             ...
# 475        NaN                             NaN
# 476        NaN                             NaN
# 477        NaN                             NaN
# 478        NaN                             NaN
# 479        NaN                             NaN
#
#      asset_fund_info_rate_output_sdg  asset_fund_info_rate_entry  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# ..                               ...                         ...
# 475                              NaN                         NaN
# 476                              NaN                         NaN
# 477                              NaN                         NaN
# 478                              NaN                         NaN
# 479                              NaN                         NaN
#
#      asset_fund_info_rate_output asset_fund_info_management_style  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 475                          NaN                              NaN
# 476                          NaN                              NaN
# 477                          NaN                              NaN
# 478                          NaN                              NaN
# 479                          NaN                              NaN
#
#     MARKET_QUOTE_IDENTIFIER asset_fund_info_manager_committee  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
# ..                      ...                               ...
# 475                     NaN                               NaN
# 476                     NaN                               NaN
# 477                     NaN                               NaN
# 478                     NaN                               NaN
# 479                     NaN                               NaN
#
#      PORT_ASSET_CONTENT_COUNT INDEX_TYPE  TELEKURS_QUOTE_PLACE_CODE  \
# 0                         NaN        NaN                        NaN
# 1                         NaN        NaN                        NaN
# 2                         NaN        NaN                        NaN
# 3                         NaN        NaN                        NaN
# 4                         NaN        NaN                        NaN
# ..                        ...        ...                        ...
# 475                       NaN        NaN                        NaN
# 476                       NaN        NaN                        NaN
# 477                       NaN        NaN                        NaN
# 478                       NaN        NaN                        NaN
# 479                       NaN        NaN                        NaN
#
#     QUOTE_PLACE IS_SRD PORT_FEED_CODE PORT_RATING_MOODYS_SHORT_TERM  \
# 0           NaN    NaN            NaN                           NaN
# 1           NaN    NaN            NaN                           NaN
# 2           NaN    NaN            NaN                           NaN
# 3           NaN    NaN            NaN                           NaN
# 4           NaN    NaN            NaN                           NaN
# ..          ...    ...            ...                           ...
# 475         NaN    NaN            NaN                           NaN
# 476         NaN    NaN            NaN                           NaN
# 477         NaN    NaN            NaN                           NaN
# 478         NaN    NaN            NaN                           NaN
# 479         NaN    NaN            NaN                           NaN
#
#      PORT_NET_EX_CASH_EQUIVALENT  PORT_NET_EX_CASH LOCK_MODE  \
# 0                            NaN               NaN       NaN
# 1                            NaN               NaN       NaN
# 2                            NaN               NaN       NaN
# 3                            NaN               NaN       NaN
# 4                            NaN               NaN       NaN
# ..                           ...               ...       ...
# 475                          NaN               NaN       NaN
# 476                          NaN               NaN       NaN
# 477                          NaN               NaN       NaN
# 478                          NaN               NaN       NaN
# 479                          NaN               NaN       NaN
#
#      EAI_PORT_AVAILABLE_CASH PORT_CLEAN_MODE  NB_COMPTE_ON_PORTFOLIO  \
# 0                        NaN             NaN                     NaN
# 1                        NaN             NaN                     NaN
# 2                        NaN             NaN                     NaN
# 3                        NaN             NaN                     NaN
# 4                        NaN             NaN                     NaN
# ..                       ...             ...                     ...
# 475                      NaN             NaN                     NaN
# 476                      NaN             NaN                     NaN
# 477                      NaN             NaN                     NaN
# 478                      NaN             NaN                     NaN
# 479                      NaN             NaN                     NaN
#
#      PORT_CASH_EQUIVALENTS EAI_PORTFOLIO_FEED_NAME PORT_RATING_SP_SHORT_TERM  \
# 0                      NaN                     NaN                       NaN
# 1                      NaN                     NaN                       NaN
# 2                      NaN                     NaN                       NaN
# 3                      NaN                     NaN                       NaN
# 4                      NaN                     NaN                       NaN
# ..                     ...                     ...                       ...
# 475                    NaN                     NaN                       NaN
# 476                    NaN                     NaN                       NaN
# 477                    NaN                     NaN                       NaN
# 478                    NaN                     NaN                       NaN
# 479                    NaN                     NaN                       NaN
#
#      PORT_BASE_NAV PORT_CURRENCY_HEDGE PORT_IS_HISTORICAL  \
# 0              NaN                 NaN                NaN
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
# ..             ...                 ...                ...
# 475            NaN                 NaN                NaN
# 476            NaN                 NaN                NaN
# 477            NaN                 NaN                NaN
# 478            NaN                 NaN                NaN
# 479            NaN                 NaN                NaN
#
#     PORT_FIRST_TRANSACTION PORT_RATING_MOODYS PORT_RATING_SP  \
# 0                      NaN                NaN            NaN
# 1                      NaN                NaN            NaN
# 2                      NaN                NaN            NaN
# 3                      NaN                NaN            NaN
# 4                      NaN                NaN            NaN
# ..                     ...                ...            ...
# 475                    NaN                NaN            NaN
# 476                    NaN                NaN            NaN
# 477                    NaN                NaN            NaN
# 478                    NaN                NaN            NaN
# 479                    NaN                NaN            NaN
#
#     PORT_NEED_RECONCILIATION PRICER_MODE PORT_TYPE  REAL_TIME_PORT_CASH  \
# 0                        NaN         NaN       NaN                  NaN
# 1                        NaN         NaN       NaN                  NaN
# 2                        NaN         NaN       NaN                  NaN
# 3                        NaN         NaN       NaN                  NaN
# 4                        NaN         NaN       NaN                  NaN
# ..                       ...         ...       ...                  ...
# 475                      NaN         NaN       NaN                  NaN
# 476                      NaN         NaN       NaN                  NaN
# 477                      NaN         NaN       NaN                  NaN
# 478                      NaN         NaN       NaN                  NaN
# 479                      NaN         NaN       NaN                  NaN
#
#     PORT_FEED_TYPE PORT_STATUS  PORT_VL PORT_RATING_FITCH  \
# 0              NaN         NaN      NaN               NaN
# 1              NaN         NaN      NaN               NaN
# 2              NaN         NaN      NaN               NaN
# 3              NaN         NaN      NaN               NaN
# 4              NaN         NaN      NaN               NaN
# ..             ...         ...      ...               ...
# 475            NaN         NaN      NaN               NaN
# 476            NaN         NaN      NaN               NaN
# 477            NaN         NaN      NaN               NaN
# 478            NaN         NaN      NaN               NaN
# 479            NaN         NaN      NaN               NaN
#
#     EAI_FRONTPORT_CASH_BY_CRCY  PORT_CASH_AVAILABLE  \
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# ..                         ...                  ...
# 475                        NaN                  NaN
# 476                        NaN                  NaN
# 477                        NaN                  NaN
# 478                        NaN                  NaN
# 479                        NaN                  NaN
#
#     PORT_RATING_FITCH_SHORT_TERM EAI_BACKPORT_CASH_BY_CRCY  PORT_CASH  \
# 0                            NaN                       NaN        NaN
# 1                            NaN                       NaN        NaN
# 2                            NaN                       NaN        NaN
# 3                            NaN                       NaN        NaN
# 4                            NaN                       NaN        NaN
# ..                           ...                       ...        ...
# 475                          NaN                       NaN        NaN
# 476                          NaN                       NaN        NaN
# 477                          NaN                       NaN        NaN
# 478                          NaN                       NaN        NaN
# 479                          NaN                       NaN        NaN
#
#      VL_DELAY_VALUE  PORT_PERCENT_CASH_AVAILABLE  PORT_PERCENT_EQUIVALENT  \
# 0               NaN                          NaN                      NaN
# 1               NaN                          NaN                      NaN
# 2               NaN                          NaN                      NaN
# 3               NaN                          NaN                      NaN
# 4               NaN                          NaN                      NaN
# ..              ...                          ...                      ...
# 475             NaN                          NaN                      NaN
# 476             NaN                          NaN                      NaN
# 477             NaN                          NaN                      NaN
# 478             NaN                          NaN                      NaN
# 479             NaN                          NaN                      NaN
#
#      PORT_PERCENT_CASH
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 475                NaN
# 476                NaN
# 477                NaN
# 478                NaN
# 479                NaN
#
# [480 rows x 190 columns]
